# %% [markdown]
# # Building, training and deploying fastai models on SageMaker example
#
# With Amazon SageMaker, you can package your own algorithms that can then be trained and deployed in the SageMaker environment. This notebook guides you through an example on how to build a custom container for SageMaker training and deployment using the popular [fast.ai](http://fast.ai) library.
#
# By packaging an algorithm in a container, you can bring almost any code to the Amazon SageMaker environment, regardless of programming language, environment, framework, or dependencies.
#
# 1. [Fast.ai on SageMaker example](#Fast.ai-on-SageMaker-example)
#   1. [Permissions](#Permissions)
#   1. [The example](#The-example)
#   1. [The presentation](#The-presentation)
# 1. [Part 1: Packaging and Uploading your Algorithm for use with Amazon SageMaker](#Part-1:-Packaging-and-Uploading-your-Algorithm-for-use-with-Amazon-SageMaker)
#     1. [An overview of Docker](#An-overview-of-Docker)
#     1. [How Amazon SageMaker runs your Docker container](#How-Amazon-SageMaker-runs-your-Docker-container)
#       1. [Running your container during training](#Running-your-container-during-training)
#         1. [The input](#The-input)
#         1. [The output](#The-output)
#       1. [Running your container during hosting](#Running-your-container-during-hosting)
#     1. [The parts of the sample container](#The-parts-of-the-sample-container)
#     1. [The Dockerfile](#The-Dockerfile)
#     1. [Building and registering the container](#Building-and-registering-the-container)
#   1. [Testing your algorithm on your local machine](#Testing-your-algorithm-on-your-local-machine)
#   1. [Download the Shirts dataset](#Download-the-Shirts-dataset)
#   1. [SageMaker Python SDK Local Training](#SageMaker-Python-SDK-Local-Training)
#   1. [Fit, Deploy, Predict](#Fit,-Deploy,-Predict)
#   1. [Making predictions using Python SDK](#Making-predictions-using-Python-SDK)
# 1. [Part 2: Training and Hosting your Algorithm in Amazon SageMaker](#Part-2:-Training-and-Hosting-your-Algorithm-in-Amazon-SageMaker)
#   1. [Set up the environment](#Set-up-the-environment)
#   1. [Create the session](#Create-the-session)
#   1. [Upload the data for training](#Upload-the-data-for-training)
#   1. [Training On SageMaker](#Training-on-SageMaker)
#   1. [Optional cleanup](#Optional-cleanup)
# 1. [Reference](#Reference)
#
# _or_ I'm impatient, just [let me see the code](#The-Dockerfile)!
#
#
# ## Permissions
#
# Running this notebook requires permissions in addition to the normal `SageMakerFullAccess` permissions. This is because it creates new repositories in Amazon ECR. The easiest way to add these permissions is simply to add the managed policy `AmazonEC2ContainerRegistryFullAccess` to the role that you used to start your notebook instance. There's no need to restart your notebook instance when you do this, the new permissions will be available immediately.
#
# ## The example
#
# In this example we show how to package a fastai container with an example application using a custom data set with a set of heavy metal t-shirts and sports shirts. By extending the SageMaker Fast.ai container we can utilize the existing training and hosting solution made to work on SageMaker found [here](https://github.com/mattmcclean/sagemaker-fastai-container). By comparison, if one were to build their own custom framework container from scratch, they would need to implement a training and hosting solution in order to use SageMaker. Here is an example showing [how to create a SageMaker TensorFlow container from scratch](https://github.com/awslabs/amazon-sagemaker-examples/blob/master/advanced_functionality/tensorflow_bring_your_own/tensorflow_bring_your_own.ipynb).
#
# In this example, we use a GPU image to support training and a CPU image to support hosting. We require a GPU image for training as we will require access to the cuda libraries to accelerate training. For hosting we do not require a GPU which can be expensive so we will use the CPU only libraries of fastai and PyTorch.
#
# If you're only using Amazon SageMaker for training or hosting, but not both, only the functionality used needs to be built into your container.
#
# ## The presentation
#
# This presentation is divided into two parts: _building_ the container and _using_ the container.

# %% [markdown]
# # Part 1: Packaging and Uploading your Algorithm for use with Amazon SageMaker
#
# ### An overview of Docker
#
# If you're familiar with Docker already, you can skip ahead to the next section.
#
# For many data scientists, Docker containers are a new technology. But they are not difficult and can significantly simplify the deployment of your software packages.
#
# Docker provides a simple way to package arbitrary code into an _image_ that is totally self-contained. Once you have an image, you can use Docker to run a _container_ based on that image. Running a container is just like running a program on the machine except that the container creates a fully self-contained environment for the program to run. Containers are isolated from each other and from the host environment, so the way your program is set up is the way it runs, no matter where you run it.
#
# Docker is more powerful than environment managers like conda or virtualenv because (a) it is completely language independent and (b) it comprises your whole operating environment, including startup commands, and environment variable.
#
# A Docker container is like a virtual machine, but it is much lighter weight. For example, a program running in a container can start in less than a second and many containers can run simultaneously on the same physical or virtual machine instance.
#
# Docker uses a simple file called a `Dockerfile` to specify how the image is assembled. An example is provided below. You can build your Docker images based on Docker images built by yourself or by others, which can simplify things quite a bit.
#
# Docker has become very popular in programming and devops communities due to its flexibility and its well-defined specification of how code can be run in its containers. It is the underpinning of many services built in the past few years, such as [Amazon ECS].
#
# Amazon SageMaker uses Docker to allow users to train and deploy arbitrary algorithms.
#
# In Amazon SageMaker, Docker containers are invoked in a one way for training and another, slightly different, way for hosting. The following sections outline how to build containers for the SageMaker environment.
#
# Some helpful links:
#
# * [Docker home page](http://www.docker.com)
# * [Getting started with Docker](https://docs.docker.com/get-started/)
# * [Dockerfile reference](https://docs.docker.com/engine/reference/builder/)
# * [`docker run` reference](https://docs.docker.com/engine/reference/run/)
#
# [Amazon ECS]: https://aws.amazon.com/ecs/
#
# ### How Amazon SageMaker runs your Docker container
#
# Because you can run the same image in training or hosting, Amazon SageMaker runs your container with the argument `train` or `serve`. How your container processes this argument depends on the container. All SageMaker deep learning framework containers already cover this requirement and will trigger your defined training algorithm and inference code.
#
# * If you specify a program as an `ENTRYPOINT` in the Dockerfile, that program will be run at startup and its first argument will be `train` or `serve`. The program can then look at that argument and decide what to do. The original `ENTRYPOINT` specified within the SageMaker PyTorch is [here](https://github.com/aws/sagemaker-pytorch-container/blob/master/docker/0.4.0/final/Dockerfile.cpu#L18).
#
# #### Running your container during training
#
# The base Docker image is based on the [SageMaker PyTorch Container](https://github.com/aws/sagemaker-pytorch-container) image as fast.ai is built on top of PyTorch. It can be found at this public [Github repo](https://github.com/mattmcclean/sagemaker-fastai-container). We have two images, one for GPU based training and a CPU based image for model hosting.
#
# Currently, our SageMaker fastai container utilizes [console_scripts](http://python-packaging.readthedocs.io/en/latest/command-line-scripts.html#the-console-scripts-entry-point) to make use of the `train` command issued at training time. The line that gets invoked during `train` is defined within the setup.py file inside [SageMaker Containers](https://github.com/aws/sagemaker-containers/blob/master/setup.py#L48), our common SageMaker deep learning container framework. When this command is run, it will invoke the [trainer class](https://github.com/aws/sagemaker-containers/blob/master/src/sagemaker_containers/cli/train.py) to run, which will finally invoke our [fastai container code](https://github.com/mattmcclean/sagemaker-fastai-container/blob/master/src/sagemaker_pytorch_container/training.py) to run your Python file.
#
# A number of files are laid out for your use, under the `/opt/ml` directory:
#
#     /opt/ml
#     ├── input
#     │   ├── config
#     │   │   ├── hyperparameters.json
#     │   │   └── resourceConfig.json
#     │   └── data
#     │       └── <channel_name>
#     │           └── <input data>
#     ├── model
#     │   └── <model files>
#     └── output
#         └── failure
#
# ##### The input
#
# * `/opt/ml/input/config` contains information to control how your program runs. `hyperparameters.json` is a JSON-formatted dictionary of hyperparameter names to values. These values are always strings, so you may need to convert them. `resourceConfig.json` is a JSON-formatted file that describes the network layout used for distributed training.
# * `/opt/ml/input/data/<channel_name>/` (for File mode) contains the input data for that channel. The channels are created based on the call to CreateTrainingJob but it's generally important that channels match algorithm expectations. The files for each channel are copied from S3 to this directory, preserving the tree structure indicated by the S3 key structure.
# * `/opt/ml/input/data/<channel_name>_<epoch_number>` (for Pipe mode) is the pipe for a given epoch. Epochs start at zero and go up by one each time you read them. There is no limit to the number of epochs that you can run, but you must close each pipe before reading the next epoch.
#
# ##### The output
#
# * `/opt/ml/model/` is the directory where you write the model that your algorithm generates. Your model can be in any format that you want. It can be a single file or a whole directory tree. SageMaker packages any files in this directory into a compressed tar archive file. This file is made available at the S3 location returned in the `DescribeTrainingJob` result.
# * `/opt/ml/output` is a directory where the algorithm can write a file `failure` that describes why the job failed. The contents of this file are returned in the `FailureReason` field of the `DescribeTrainingJob` result. For jobs that succeed, there is no reason to write this file as it is ignored.
#
# #### Running your container during hosting
#
# Hosting has a very different model than training because hosting is reponding to inference requests that come in via HTTP. Currently, the SageMaker PyTorch containers [uses](https://github.com/aws/sagemaker-pytorch-container/blob/master/src/sagemaker_pytorch_container/serving.py#L103) our [recommended Python serving stack](https://github.com/aws/sagemaker-containers/blob/master/src/sagemaker_containers/_server.py#L44) to provide robust and scalable serving of inference requests:
#
# ![Request serving stack](img/stack.png)
#
# Amazon SageMaker uses two URLs in the container:
#
# * `/ping` receives `GET` requests from the infrastructure. Your program returns 200 if the container is up and accepting requests.
# * `/invocations` is the endpoint that receives client inference `POST` requests. The format of the request and the response is up to the algorithm. If the client supplied `ContentType` and `Accept` headers, these are passed in as well.
#
# The container has the model files in the same place that they were written to during training:
#
#     /opt/ml
#     └── model
#         └── <model files>

# %% [markdown]
# ### The parts of the sample container
#
# The root directory has all the components you need to extend the SageMaker fast.ai container to use as an sample algorithm:
#
#     .
#     ├── Dockerfile
#     ├── build_and_push.sh
#     └── src
#         ├── shirts.py
#
# Let's discuss each of these in turn:
#
# * __`Dockerfile`__ describes how to build your Docker container image. More details are provided below.
# * __`build_and_push.sh`__ is a script that uses the Dockerfile to build your container GPU and CPU images and then push them to ECR.
# * __`src`__ is the directory which contains our user code to be invoked.
#
# In this simple application, we install only one file in the container based on [Lesson 1](https://github.com/fastai/fastai/blob/master/courses/dl1/lesson1.ipynb) of the fast.ai MOOC course. You may only need that many, but if you have many supporting routines, you may wish to install more.
#
# The files that we put in the container are:
#
# * __`shirts.py`__ is the program based a custom image classification data set between photos of either heavy metal t-shirts or sports shirts that implements our training algorithm and handles loading our model for inferences.

# %% [markdown]
# ### The Dockerfile
#
# The Dockerfile describes the image that we want to build. You can think of it as describing the complete operating system installation of the system that you want to run. A Docker container running is quite a bit lighter than a full operating system, however, because it takes advantage of Linux on the host machine for the basic operations.
#
# We start from the [SageMaker fast.ai image](https://hub.docker.com/r/mattmcclean/sagemaker-fastai/) as the base image. This contains the PyTorch and fastai binaries as well as the SageMaker specific libraries explained earlier. The base image is an DockerHub image with the following pattern.
#
# `{account}/sagemaker-fastai:{framework_version}-{processor_type}-{python_version}`
#
# Here is an explanation of each field.
# * __`account`__ - The DockerHub account to pull the base image from. Currently it is `mattmcclean`.
# * __`framework_version`__ - The version of the fastai library. Currently is `1.0`
# * __`processor_type`__ - CPU or GPU. We pass this as a Docker build arguement depending on the kind of image we want. Defaults to `gpu`.
# * __`python_version`__ - The supported version of Python. Currently default is `py37`
#
# So the SageMaker fast.ai DockerHub image would be:
# `mattmcclean/sagemaker-fastai:1.0-gpu-py37`
#
# ```
# docker pull mattmcclean/sagemaker-fastai:1.0-gpu-py37
# docker pull mattmcclean/sagemaker-fastai:1.0-cpu-py37
# ```

# %%
# %%bash
# docker pull mattmcclean/sagemaker-fastai:1.0-gpu-py37
# docker tag mattmcclean/sagemaker-fastai:1.0-gpu-py37 sagemaker-fastai:1.0-gpu-py37
# Out:
# 1.0-gpu-py37: Pulling from mattmcclean/sagemaker-fastai
# Digest: sha256:ef4b7563021b26b37d44a5985a8a552da232309625e218af3fe0e54107f956ac
# Status: Image is up to date for mattmcclean/sagemaker-fastai:1.0-gpu-py37

# %% [markdown]
# You can also build your own base Docker image by performing the following steps:
# 1. Clone the Github repo with the command:
#
#     `
#     git clone https://github.com/mattmcclean/sagemaker-fastai-container
#     `
#
#
# 2. Build the GPU and CPU Docker base images and push to your own ECR respository with the commands:
#
#     `
#     cd sagemaker-fastai-container
#     ./build_and_push.sh
#     `

# %% [markdown]
# ## Testing your algorithm on your local machine
#
# When you're packaging your first algorithm to use with Amazon SageMaker, you probably want to test it yourself to make sure it's working correctly. We use the [SageMaker Python SDK](https://github.com/aws/sagemaker-python-sdk) to test both locally and on SageMaker. For more examples with the SageMaker Python SDK, see [Amazon SageMaker Examples](https://github.com/awslabs/amazon-sagemaker-examples/tree/master/sagemaker-python-sdk). In order to test our algorithm, we need our dataset.

# %%
# %%bash
# pushd utils
# ./setup.sh
# Out:
# ~/SageMaker/sagemaker-fastai-example/utils ~/SageMaker/sagemaker-fastai-example
# nvidia-docker2 already installed. updating default docker config
# SageMaker instance routing for Docker is ok. We are good to go!

# %% [markdown]
# ## Download the Shirts dataset
# We will be utilizing a custom data set with a mixture of metal and sport shirts for training.

# %%
# %mkdir -p data/shirts
# !wget https://s3-eu-west-1.amazonaws.com/sagemaker-934676248949-eu-west-1/data/shirts_imgs.tar.gz
# !tar zxf shirts_imgs.tar.gz -C data/shirts
# !rm shirts_imgs.tar.gz
# Out:
# --2018-11-19 07:16:04--  https://s3-eu-west-1.amazonaws.com/sagemaker-934676248949-eu-west-1/data/shirts_imgs.tar.gz
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.104.82
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.104.82|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 221495367 (211M) [application/x-tar]
# Saving to: ‘shirts_imgs.tar.gz’
#
# shirts_imgs.tar.gz  100%[===================>] 211.23M  10.6MB/s    in 23s
#
# 2018-11-19 07:16:28 (9.07 MB/s) - ‘shirts_imgs.tar.gz’ saved [221495367/221495367]

# %%
import os
DATA_PATH=f'{os.getcwd()}/data/shirts'

# %%
# %ls {DATA_PATH}
# Out:
# metal/  models/  sport/

# %% [markdown]
# ## SageMaker Python SDK Local Training
# To represent our training, we use the Estimator class, which needs to be configured in five steps.
# 1. IAM role - our AWS execution role
# 2. train_instance_count - number of instances to use for training.
# 3. train_instance_type - type of instance to use for training. For training locally, we specify `local` or `local_gpu`.
# 4. image_name - our custom Fast.ai Docker image we created.
# 5. hyperparameters - hyperparameters we want to pass.
#
# Let's start with setting up our IAM role. We make use of a helper function within the Python SDK. This function throw an exception if run outside of a SageMaker notebook instance, as it gets metadata from the notebook instance. If running outside, you must provide an IAM role with proper access stated above in [Permissions](#Permissions).

# %%
from sagemaker import get_execution_role

role = get_execution_role()

# %% [markdown]
# ## Fit, Deploy, Predict
#
# Now that the rest of our estimator is configured, we can call `fit()` with the path to our local Shirts dataset prefixed with `file://`. This invokes our fast.ai container with 'train' and passes in our hyperparameters and other metadata as json files in /opt/ml/input/config within the container to our program entry point defined in the Dockerfile.
#
# After our training has succeeded, our training algorithm outputs our trained model within the /opt/ml/model directory, which is used to handle predictions.
#
# We can then call `deploy()` with an instance_count and instance_type, which is 1 and `local`. This invokes our fast.ai container with 'serve', which setups our container to handle prediction requests as defined [here](https://github.com/aws/sagemaker-pytorch-container/blob/master/src/sagemaker_pytorch_container/serving.py#L103). What is returned is a predictor, which is used to make inferences against our trained model.
#
# After our prediction, we can delete our endpoint.
#
# We recommend testing and training your training algorithm locally first, as it provides quicker iterations and better debuggability.

# %%
base_image_name = 'sagemaker-fastai'
SRC_PATH = f'{os.getcwd()}/src/shirts'

# %%
import os
import subprocess

instance_type = 'local'
image_name = f'{base_image_name}:1.0-cpu-py37'

if subprocess.call('nvidia-smi') == 0:
    ## Set type to GPU if one is present
    instance_type = 'local_gpu'
    image_name = f'{base_image_name}:1.0-gpu-py37'
    
print("Instance type = " + instance_type)
print("Image = " + image_name)
# Out:
# Instance type = local_gpu
# Image = sagemaker-fastai:1.0-gpu-py37

# %%
from sagemaker.local import local_session
# Create local session
sagemaker_session = local_session.LocalSession()
sagemaker_session.config = {'local': {'local_code': True }}

# %%
from sagemaker.pytorch import PyTorch

hyperparameters = {'epochs': 4, 'batch-size': 64}

estimator = PyTorch(entry_point='shirts.py',
                    source_dir=SRC_PATH,
                    role=role,
                    train_instance_count=1,
                    train_instance_type=instance_type,
                    image_name=f'698042698196.dkr.ecr.us-west-2.amazonaws.com/sagemaker-fastai:1.0-gpu-py37',
                    sagemaker_session=sagemaker_session,
                    hyperparameters=hyperparameters)

estimator.fit(f'file://{DATA_PATH}')
# Out:
# WARNING:sagemaker:No framework_version specified, defaulting to version 0.4.
# INFO:sagemaker:Creating training-job with name: sagemaker-fastai-2018-11-19-07-59-51-380
# Creating tmptx6p8j7k_algo-1-8O455_1_f1bad98741c5 ...
# Attaching to tmptx6p8j7k_algo-1-8O455_1_d6bfec9f2f582mdone
# algo-1-8O455_1_d6bfec9f2f58 | 2018-11-19 07:59:53,372 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# algo-1-8O455_1_d6bfec9f2f58 | 2018-11-19 07:59:53,372 sagemaker-containers INFO     Failed to parse hyperparameter sagemaker_submit_directory value /opt/ml/code to Json.
# algo-1-8O455_1_d6bfec9f2f58 | Returning the value itself
# algo-1-8O455_1_d6bfec9f2f58 | 2018-11-19 07:59:53,394 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# algo-1-8O455_1_d6bfec9f2f58 | 2018-11-19 07:59:53,397 sagemaker_pytorch_container.training INFO     Invoking user training script.
# algo-1-8O455_1_d6bfec9f2f58 | 2018-11-19 07:59:53,399 sagemaker-containers INFO     Installing module with the following command:
# algo-1-8O455_1_d6bfec9f2f58 | /usr/local/bin/python -m pip install -vvv -U .
# algo-1-8O455_1_d6bfec9f2f58 | Created temporary directory: /tmp/pip-ephem-wheel-cache-hyxnqy2a
# algo-1-8O455_1_d6bfec9f2f58 | Created temporary directory: /tmp/pip-req-tracker-42wi5fx2
# algo-1-8O455_1_d6bfec9f2f58 | Created requirements tracker '/tmp/pip-req-tracker-42wi5fx2'
# algo-1-8O455_1_d6bfec9f2f58 | Created temporary directory: /tmp/pip-install-d7b9ku6b
# algo-1-8O455_1_d6bfec9f2f58 | Processing /opt/ml/code
# algo-1-8O455_1_d6bfec9f2f58 |   Created temporary directory: /tmp/pip-req-build-39o794z0
# algo-1-8O455_1_d6bfec9f2f58 |   Added file:///opt/ml/code to build tracker '/tmp/pip-req-tracker-42wi5fx2'
# algo-1-8O455_1_d6bfec9f2f58 |   Running setup.py (path:/tmp/pip-req-build-39o794z0/setup.py) egg_info for package from file:///opt/ml/code
# algo-1-8O455_1_d6bfec9f2f58 |     Running command python setup.py egg_info
# algo-1-8O455_1_d6bfec9f2f58 |     WARNING: '' not a valid package name; please use only .-separated package names in setup.py
# algo-1-8O455_1_d6bfec9f2f58 |     running egg_info
# algo-1-8O455_1_d6bfec9f2f58 |     creating pip-egg-info/shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |     writing pip-egg-info/shirts.egg-info/PKG-INFO
# algo-1-8O455_1_d6bfec9f2f58 |     writing dependency_links to pip-egg-info/shirts.egg-info/dependency_links.txt
# algo-1-8O455_1_d6bfec9f2f58 |     writing top-level names to pip-egg-info/shirts.egg-info/top_level.txt
# algo-1-8O455_1_d6bfec9f2f58 |     writing manifest file 'pip-egg-info/shirts.egg-info/SOURCES.txt'
# algo-1-8O455_1_d6bfec9f2f58 |     reading manifest file 'pip-egg-info/shirts.egg-info/SOURCES.txt'
# algo-1-8O455_1_d6bfec9f2f58 |     reading manifest template 'MANIFEST.in'
# algo-1-8O455_1_d6bfec9f2f58 |     warning: no previously-included files matching '__pycache__*' found under directory '.'
# algo-1-8O455_1_d6bfec9f2f58 |     warning: no previously-included files matching '*.pyc' found under directory '.'
# algo-1-8O455_1_d6bfec9f2f58 |     warning: no previously-included files matching '*.pyo' found under directory '.'
# algo-1-8O455_1_d6bfec9f2f58 |     writing manifest file 'pip-egg-info/shirts.egg-info/SOURCES.txt'
# algo-1-8O455_1_d6bfec9f2f58 |   Source in /tmp/pip-req-build-39o794z0 has version 1.0.0, which satisfies requirement shirts==1.0.0 from file:///opt/ml/code
# algo-1-8O455_1_d6bfec9f2f58 |   Removed shirts==1.0.0 from file:///opt/ml/code from build tracker '/tmp/pip-req-tracker-42wi5fx2'
# algo-1-8O455_1_d6bfec9f2f58 | Could not parse version from link: file:///opt/ml/code
# algo-1-8O455_1_d6bfec9f2f58 | Building wheels for collected packages: shirts
# algo-1-8O455_1_d6bfec9f2f58 |   Created temporary directory: /tmp/pip-wheel-a29tx_ja
# algo-1-8O455_1_d6bfec9f2f58 |   Running setup.py bdist_wheel for shirts ...   Destination directory: /tmp/pip-wheel-a29tx_ja
# algo-1-8O455_1_d6bfec9f2f58 |   Running command /usr/local/bin/python -u -c "import setuptools, tokenize;__file__='/tmp/pip-req-build-39o794z0/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/pip-wheel-a29tx_ja --python-tag cp37
# algo-1-8O455_1_d6bfec9f2f58 |   WARNING: '' not a valid package name; please use only .-separated package names in setup.py
# algo-1-8O455_1_d6bfec9f2f58 |   running bdist_wheel
# algo-1-8O455_1_d6bfec9f2f58 |   The [wheel] section is deprecated. Use [bdist_wheel] instead.
# algo-1-8O455_1_d6bfec9f2f58 |   running build
# algo-1-8O455_1_d6bfec9f2f58 |   running build_py
# algo-1-8O455_1_d6bfec9f2f58 |   creating build
# algo-1-8O455_1_d6bfec9f2f58 |   creating build/lib
# algo-1-8O455_1_d6bfec9f2f58 |   copying setup.py -> build/lib
# algo-1-8O455_1_d6bfec9f2f58 |   copying shirts.py -> build/lib
# algo-1-8O455_1_d6bfec9f2f58 |   running egg_info
# algo-1-8O455_1_d6bfec9f2f58 |   creating shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   writing shirts.egg-info/PKG-INFO
# algo-1-8O455_1_d6bfec9f2f58 |   writing dependency_links to shirts.egg-info/dependency_links.txt
# algo-1-8O455_1_d6bfec9f2f58 |   writing top-level names to shirts.egg-info/top_level.txt
# algo-1-8O455_1_d6bfec9f2f58 |   writing manifest file 'shirts.egg-info/SOURCES.txt'
# algo-1-8O455_1_d6bfec9f2f58 |   reading manifest file 'shirts.egg-info/SOURCES.txt'
# algo-1-8O455_1_d6bfec9f2f58 |   reading manifest template 'MANIFEST.in'
# algo-1-8O455_1_d6bfec9f2f58 |   warning: no previously-included files matching '__pycache__*' found under directory '.'
# algo-1-8O455_1_d6bfec9f2f58 |   warning: no previously-included files matching '*.pyc' found under directory '.'
# algo-1-8O455_1_d6bfec9f2f58 |   warning: no previously-included files matching '*.pyo' found under directory '.'
# algo-1-8O455_1_d6bfec9f2f58 |   writing manifest file 'shirts.egg-info/SOURCES.txt'
# algo-1-8O455_1_d6bfec9f2f58 |   copying MANIFEST.in -> build/lib
# algo-1-8O455_1_d6bfec9f2f58 |   copying setup.cfg -> build/lib
# algo-1-8O455_1_d6bfec9f2f58 |   copying pip-delete-this-directory.txt -> build/lib
# algo-1-8O455_1_d6bfec9f2f58 |   creating build/lib/build
# algo-1-8O455_1_d6bfec9f2f58 |   creating build/lib/build/lib
# algo-1-8O455_1_d6bfec9f2f58 |   copying build/lib/setup.py -> build/lib/build/lib
# algo-1-8O455_1_d6bfec9f2f58 |   copying build/lib/shirts.py -> build/lib/build/lib
# algo-1-8O455_1_d6bfec9f2f58 |   creating build/lib/pip-egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   creating build/lib/pip-egg-info/shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   copying pip-egg-info/shirts.egg-info/PKG-INFO -> build/lib/pip-egg-info/shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   copying pip-egg-info/shirts.egg-info/SOURCES.txt -> build/lib/pip-egg-info/shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   copying pip-egg-info/shirts.egg-info/dependency_links.txt -> build/lib/pip-egg-info/shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   copying pip-egg-info/shirts.egg-info/top_level.txt -> build/lib/pip-egg-info/shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   creating build/lib/shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   copying shirts.egg-info/PKG-INFO -> build/lib/shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   copying shirts.egg-info/SOURCES.txt -> build/lib/shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   copying shirts.egg-info/dependency_links.txt -> build/lib/shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   copying shirts.egg-info/top_level.txt -> build/lib/shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   warning: build_py: byte-compiling is disabled, skipping.
# algo-1-8O455_1_d6bfec9f2f58 |
# algo-1-8O455_1_d6bfec9f2f58 |   installing to build/bdist.linux-x86_64/wheel
# algo-1-8O455_1_d6bfec9f2f58 |   running install
# algo-1-8O455_1_d6bfec9f2f58 |   running install_lib
# algo-1-8O455_1_d6bfec9f2f58 |   creating build/bdist.linux-x86_64
# algo-1-8O455_1_d6bfec9f2f58 |   creating build/bdist.linux-x86_64/wheel
# algo-1-8O455_1_d6bfec9f2f58 |   creating build/bdist.linux-x86_64/wheel/pip-egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   creating build/bdist.linux-x86_64/wheel/pip-egg-info/shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   copying build/lib/pip-egg-info/shirts.egg-info/top_level.txt -> build/bdist.linux-x86_64/wheel/pip-egg-info/shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   copying build/lib/pip-egg-info/shirts.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/wheel/pip-egg-info/shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   copying build/lib/pip-egg-info/shirts.egg-info/PKG-INFO -> build/bdist.linux-x86_64/wheel/pip-egg-info/shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   copying build/lib/pip-egg-info/shirts.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/wheel/pip-egg-info/shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   copying build/lib/pip-delete-this-directory.txt -> build/bdist.linux-x86_64/wheel
# algo-1-8O455_1_d6bfec9f2f58 |   copying build/lib/setup.py -> build/bdist.linux-x86_64/wheel
# algo-1-8O455_1_d6bfec9f2f58 |   copying build/lib/shirts.py -> build/bdist.linux-x86_64/wheel
# algo-1-8O455_1_d6bfec9f2f58 |   creating build/bdist.linux-x86_64/wheel/build
# algo-1-8O455_1_d6bfec9f2f58 |   creating build/bdist.linux-x86_64/wheel/build/lib
# algo-1-8O455_1_d6bfec9f2f58 |   copying build/lib/build/lib/setup.py -> build/bdist.linux-x86_64/wheel/build/lib
# algo-1-8O455_1_d6bfec9f2f58 |   copying build/lib/build/lib/shirts.py -> build/bdist.linux-x86_64/wheel/build/lib
# algo-1-8O455_1_d6bfec9f2f58 |   creating build/bdist.linux-x86_64/wheel/shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   copying build/lib/shirts.egg-info/top_level.txt -> build/bdist.linux-x86_64/wheel/shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   copying build/lib/shirts.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/wheel/shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   copying build/lib/shirts.egg-info/PKG-INFO -> build/bdist.linux-x86_64/wheel/shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   copying build/lib/shirts.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/wheel/shirts.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   copying build/lib/setup.cfg -> build/bdist.linux-x86_64/wheel
# algo-1-8O455_1_d6bfec9f2f58 |   copying build/lib/MANIFEST.in -> build/bdist.linux-x86_64/wheel
# algo-1-8O455_1_d6bfec9f2f58 |   warning: install_lib: byte-compiling is disabled, skipping.
# algo-1-8O455_1_d6bfec9f2f58 |
# algo-1-8O455_1_d6bfec9f2f58 |   running install_egg_info
# algo-1-8O455_1_d6bfec9f2f58 |   Copying shirts.egg-info to build/bdist.linux-x86_64/wheel/shirts-1.0.0-py3.7.egg-info
# algo-1-8O455_1_d6bfec9f2f58 |   running install_scripts
# algo-1-8O455_1_d6bfec9f2f58 |   creating build/bdist.linux-x86_64/wheel/shirts-1.0.0.dist-info/WHEEL
# algo-1-8O455_1_d6bfec9f2f58 |   creating '/tmp/pip-wheel-a29tx_ja/shirts-1.0.0-py2.py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
# algo-1-8O455_1_d6bfec9f2f58 |   adding 'MANIFEST.in'
# algo-1-8O455_1_d6bfec9f2f58 |   adding 'pip-delete-this-directory.txt'
# algo-1-8O455_1_d6bfec9f2f58 |   adding 'setup.cfg'
# algo-1-8O455_1_d6bfec9f2f58 |   adding 'setup.py'
# algo-1-8O455_1_d6bfec9f2f58 |   adding 'shirts.py'
# algo-1-8O455_1_d6bfec9f2f58 |   adding 'build/lib/setup.py'
# algo-1-8O455_1_d6bfec9f2f58 |   adding 'build/lib/shirts.py'
# algo-1-8O455_1_d6bfec9f2f58 |   adding 'pip-egg-info/shirts.egg-info/PKG-INFO'
# algo-1-8O455_1_d6bfec9f2f58 |   adding 'pip-egg-info/shirts.egg-info/SOURCES.txt'
# algo-1-8O455_1_d6bfec9f2f58 |   adding 'pip-egg-info/shirts.egg-info/dependency_links.txt'
# algo-1-8O455_1_d6bfec9f2f58 |   adding 'pip-egg-info/shirts.egg-info/top_level.txt'
# algo-1-8O455_1_d6bfec9f2f58 |   adding 'shirts.egg-info/PKG-INFO'
# algo-1-8O455_1_d6bfec9f2f58 |   adding 'shirts.egg-info/SOURCES.txt'
# algo-1-8O455_1_d6bfec9f2f58 |   adding 'shirts.egg-info/dependency_links.txt'
# algo-1-8O455_1_d6bfec9f2f58 |   adding 'shirts.egg-info/top_level.txt'
# algo-1-8O455_1_d6bfec9f2f58 |   adding 'shirts-1.0.0.dist-info/METADATA'
# algo-1-8O455_1_d6bfec9f2f58 |   adding 'shirts-1.0.0.dist-info/WHEEL'
# algo-1-8O455_1_d6bfec9f2f58 |   adding 'shirts-1.0.0.dist-info/top_level.txt'
# algo-1-8O455_1_d6bfec9f2f58 |   adding 'shirts-1.0.0.dist-info/RECORD'
# algo-1-8O455_1_d6bfec9f2f58 |   removing build/bdist.linux-x86_64/wheel
# algo-1-8O455_1_d6bfec9f2f58 | done
# algo-1-8O455_1_d6bfec9f2f58 |   Stored in directory: /tmp/pip-ephem-wheel-cache-hyxnqy2a/wheels/35/24/16/37574d11bf9bde50616c67372a334f94fa8356bc7164af8ca3
# algo-1-8O455_1_d6bfec9f2f58 |   Removing source in /tmp/pip-req-build-39o794z0
# algo-1-8O455_1_d6bfec9f2f58 | Successfully built shirts
# algo-1-8O455_1_d6bfec9f2f58 | Installing collected packages: shirts
# algo-1-8O455_1_d6bfec9f2f58 |
# algo-1-8O455_1_d6bfec9f2f58 |   Removing source in /tmp/pip-install-d7b9ku6b/shirts
# algo-1-8O455_1_d6bfec9f2f58 | Successfully installed shirts-1.0.0
# algo-1-8O455_1_d6bfec9f2f58 | Cleaning up...
# algo-1-8O455_1_d6bfec9f2f58 | Removed build tracker '/tmp/pip-req-tracker-42wi5fx2'
# algo-1-8O455_1_d6bfec9f2f58 | 2018-11-19 07:59:54,549 sagemaker-containers INFO     Failed to parse hyperparameter sagemaker_submit_directory value /opt/ml/code to Json.
# algo-1-8O455_1_d6bfec9f2f58 | Returning the value itself
# algo-1-8O455_1_d6bfec9f2f58 | 2018-11-19 07:59:54,571 sagemaker-containers INFO     Invoking user script
# algo-1-8O455_1_d6bfec9f2f58 |
# algo-1-8O455_1_d6bfec9f2f58 | Training Env:
# algo-1-8O455_1_d6bfec9f2f58 |
# algo-1-8O455_1_d6bfec9f2f58 | {
# algo-1-8O455_1_d6bfec9f2f58 |     "additional_framework_parameters": {},
# algo-1-8O455_1_d6bfec9f2f58 |     "channel_input_dirs": {
# algo-1-8O455_1_d6bfec9f2f58 |         "training": "/opt/ml/input/data/training"
# algo-1-8O455_1_d6bfec9f2f58 |     },
# algo-1-8O455_1_d6bfec9f2f58 |     "current_host": "algo-1-8O455",
# algo-1-8O455_1_d6bfec9f2f58 |     "framework_module": "sagemaker_pytorch_container.training:main",
# algo-1-8O455_1_d6bfec9f2f58 |     "hosts": [
# algo-1-8O455_1_d6bfec9f2f58 |         "algo-1-8O455"
# algo-1-8O455_1_d6bfec9f2f58 |     ],
# algo-1-8O455_1_d6bfec9f2f58 |     "hyperparameters": {
# algo-1-8O455_1_d6bfec9f2f58 |         "epochs": 4,
# algo-1-8O455_1_d6bfec9f2f58 |         "batch-size": 64
# algo-1-8O455_1_d6bfec9f2f58 |     },
# algo-1-8O455_1_d6bfec9f2f58 |     "input_config_dir": "/opt/ml/input/config",
# algo-1-8O455_1_d6bfec9f2f58 |     "input_data_config": {
# algo-1-8O455_1_d6bfec9f2f58 |         "training": {
# algo-1-8O455_1_d6bfec9f2f58 |             "TrainingInputMode": "File"
# algo-1-8O455_1_d6bfec9f2f58 |         }
# algo-1-8O455_1_d6bfec9f2f58 |     },
# algo-1-8O455_1_d6bfec9f2f58 |     "input_dir": "/opt/ml/input",
# algo-1-8O455_1_d6bfec9f2f58 |     "job_name": "sagemaker-fastai-2018-11-19-07-59-51-380",
# algo-1-8O455_1_d6bfec9f2f58 |     "log_level": 20,
# algo-1-8O455_1_d6bfec9f2f58 |     "model_dir": "/opt/ml/model",
# algo-1-8O455_1_d6bfec9f2f58 |     "module_dir": "/opt/ml/code",
# algo-1-8O455_1_d6bfec9f2f58 |     "module_name": "shirts",
# algo-1-8O455_1_d6bfec9f2f58 |     "network_interface_name": "ethwe",
# algo-1-8O455_1_d6bfec9f2f58 |     "num_cpus": 8,
# algo-1-8O455_1_d6bfec9f2f58 |     "num_gpus": 1,
# algo-1-8O455_1_d6bfec9f2f58 |     "output_data_dir": "/opt/ml/output/data",
# algo-1-8O455_1_d6bfec9f2f58 |     "output_dir": "/opt/ml/output",
# algo-1-8O455_1_d6bfec9f2f58 |     "resource_config": {
# algo-1-8O455_1_d6bfec9f2f58 |         "current_host": "algo-1-8O455",
# algo-1-8O455_1_d6bfec9f2f58 |         "hosts": [
# algo-1-8O455_1_d6bfec9f2f58 |             "algo-1-8O455"
# algo-1-8O455_1_d6bfec9f2f58 |         ]
# algo-1-8O455_1_d6bfec9f2f58 |     }
# algo-1-8O455_1_d6bfec9f2f58 | }
# algo-1-8O455_1_d6bfec9f2f58 |
# algo-1-8O455_1_d6bfec9f2f58 | Environment variables:
# algo-1-8O455_1_d6bfec9f2f58 |
# algo-1-8O455_1_d6bfec9f2f58 | SM_HOSTS=["algo-1-8O455"]
# algo-1-8O455_1_d6bfec9f2f58 | SM_NETWORK_INTERFACE_NAME=ethwe
# algo-1-8O455_1_d6bfec9f2f58 | SM_HPS={"batch-size":64,"epochs":4}
# algo-1-8O455_1_d6bfec9f2f58 | SM_FRAMEWORK_PARAMS={}
# algo-1-8O455_1_d6bfec9f2f58 | SM_RESOURCE_CONFIG={"current_host":"algo-1-8O455","hosts":["algo-1-8O455"]}
# algo-1-8O455_1_d6bfec9f2f58 | SM_INPUT_DATA_CONFIG={"training":{"TrainingInputMode":"File"}}
# algo-1-8O455_1_d6bfec9f2f58 | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-8O455_1_d6bfec9f2f58 | SM_CHANNELS=["training"]
# algo-1-8O455_1_d6bfec9f2f58 | SM_CURRENT_HOST=algo-1-8O455
# algo-1-8O455_1_d6bfec9f2f58 | SM_MODULE_NAME=shirts
# algo-1-8O455_1_d6bfec9f2f58 | SM_LOG_LEVEL=20
# algo-1-8O455_1_d6bfec9f2f58 | SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# algo-1-8O455_1_d6bfec9f2f58 | SM_INPUT_DIR=/opt/ml/input
# algo-1-8O455_1_d6bfec9f2f58 | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-8O455_1_d6bfec9f2f58 | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-8O455_1_d6bfec9f2f58 | SM_NUM_CPUS=8
# algo-1-8O455_1_d6bfec9f2f58 | SM_NUM_GPUS=1
# algo-1-8O455_1_d6bfec9f2f58 | SM_MODEL_DIR=/opt/ml/model
# algo-1-8O455_1_d6bfec9f2f58 | SM_MODULE_DIR=/opt/ml/code
# algo-1-8O455_1_d6bfec9f2f58 | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1-8O455","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1-8O455"],"hyperparameters":{"batch-size":64,"epochs":4},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","job_name":"sagemaker-fastai-2018-11-19-07-59-51-380","log_level":20,"model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"shirts","network_interface_name":"ethwe","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","resource_config":{"current_host":"algo-1-8O455","hosts":["algo-1-8O455"]}}
# algo-1-8O455_1_d6bfec9f2f58 | SM_USER_ARGS=["--batch-size","64","--epochs","4"]
# algo-1-8O455_1_d6bfec9f2f58 | SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# algo-1-8O455_1_d6bfec9f2f58 | SM_HP_EPOCHS=4
# algo-1-8O455_1_d6bfec9f2f58 | SM_HP_BATCH-SIZE=64
# algo-1-8O455_1_d6bfec9f2f58 |
# algo-1-8O455_1_d6bfec9f2f58 | Invoking script with the following command:
# algo-1-8O455_1_d6bfec9f2f58 |
# algo-1-8O455_1_d6bfec9f2f58 | /usr/local/bin/python -m shirts --batch-size 64 --epochs 4
# algo-1-8O455_1_d6bfec9f2f58 |
# algo-1-8O455_1_d6bfec9f2f58 |
# algo-1-8O455_1_d6bfec9f2f58 | Called _train method with model arch: resnet34, batch size: 64, image size: 224, epochs: 4
# algo-1-8O455_1_d6bfec9f2f58 | Getting training data from dir: /opt/ml/input/data/training
# algo-1-8O455_1_d6bfec9f2f58 | Model architecture is resnet34
# algo-1-8O455_1_d6bfec9f2f58 | Creating pretrained conv net
# algo-1-8O455_1_d6bfec9f2f58 | Fit four cycles
# algo-1-8O455_1_d6bfec9f2f58 | epoch  train_loss  valid_loss  accuracy
# 1      0.486608    0.157434    0.922481
# 2      0.303957    0.156520    0.926357
# 3      0.223464    0.133509    0.945736
# 4      0.177759    0.125845    0.949612
# algo-1-8O455_1_d6bfec9f2f58 | Unfreeze and run 4 more cycles
# algo-1-8O455_1_d6bfec9f2f58 | epoch  train_loss  valid_loss  accuracy
# 1      0.117112    0.120233    0.957364
# 2      0.076507    0.183849    0.957364
# 3      0.056789    0.187036    0.953488
# 4      0.043954    0.172886    0.953488
# algo-1-8O455_1_d6bfec9f2f58 | Saving model weights to dir: /opt/ml/model
# algo-1-8O455_1_d6bfec9f2f58 | 2018-11-19 08:03:11,241 sagemaker-containers INFO     Reporting training SUCCESS
# tmptx6p8j7k_algo-1-8O455_1_d6bfec9f2f58 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %% [markdown]
# ## Making predictions using Python SDK
#
# To make predictions, we will use a few images, from the test loader, converted into a json format to send as an inference request.
#
# We will do predictions using a different Docker image that is CPU only rather than GPU based that was used for training.
#
# The reponse will be tensors containing the probabilities of each image belonging to one of the 2 classes. Based on the highest probability we will map that index to the corresponding class in our output.

# %%
import os, random
from PIL import Image

# %%
from sagemaker.predictor import RealTimePredictor, json_deserializer

class ImagePredictor(RealTimePredictor):
    def __init__(self, endpoint_name, sagemaker_session):
        super(ImagePredictor, self).__init__(endpoint_name, sagemaker_session=sagemaker_session, serializer=None, 
                                            deserializer=json_deserializer, content_type='image/jpeg')

# %%
model = estimator.create_model()
model.predictor_cls=ImagePredictor

# %%
predictor = model.deploy(1, 'local')

# %%
from PIL import Image
import requests
from io import BytesIO

# %%
# Motorhead T-Shirt
#url = 'https://images.backstreetmerch.com/images/products/bands/clothing/mthd/bsi_mthd281.jpg'
# Judas Priest T-Shirt
#url = 'https://thumbs2.ebaystatic.com/d/l225/m/m7Lc1qRuFN3oFIlQla5V0IA.jpg'
# Australia Rugby T-Shirt
#url = 'https://www.lovell-rugby.co.uk/products/products_580x387/40378.jpg'
# Chicago Bulls top
#url = 'https://i.ebayimg.com/images/g/qc0AAOSwBahVN~qm/s-l300.jpg'
# Masters Golf Shirt
url = 'https://s-media-cache-ak0.pinimg.com/originals/29/6a/15/296a15200e7dd3ed08e12d9052ea4f97.jpg'
img_bytes = requests.get(url).content
img = Image.open(BytesIO(img_bytes))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=750x1000 at 0x7F562FEE0A90>

# %%
response = predictor.predict(img_bytes)
response
# Out:
# {'class': 'metal', 'confidence': 0.7310577630996704}

# %%
predictor.delete_endpoint()
# Out:
# INFO:sagemaker:Deleting endpoint with name: sagemaker-fastai-2018-11-19-07-59-51-380

# %% [markdown]
# # Part 2: Training and Hosting your Algorithm in Amazon SageMaker
# Once you have your container packaged, you can use it to train and serve models. Let's do that with the algorithm we made above.
#
# ## Set up the environment
# Here we specify the bucket to use and the role that is used for working with SageMaker.

# %%
# S3 prefix
prefix = 'DEMO-shirt-classifier'

# %% [markdown]
# ## Create the session
#
# The session remembers our connection parameters to SageMaker. We use it to perform all of our SageMaker operations.

# %%
import sagemaker as sage

sess = sage.Session()

# %% [markdown]
# ## Upload the data for training
#
# We will use the tools provided by the SageMaker Python SDK to upload the data to a default bucket.

# %%
data_location = sess.upload_data(DATA_PATH, key_prefix=prefix)

# %%
data_location

# %%
# run if data already uploaded
# data_location = 's3://' + sess.default_bucket() + '/' + prefix

# %% [markdown]
# ## Training on SageMaker
# Training a model on SageMaker with the Python SDK is done in a way that is similar to the way we trained it locally. This is done by changing our train_instance_type from `local` to one of our [supported EC2 instance types](https://aws.amazon.com/sagemaker/pricing/instance-types/).
#
# In addition, we must now specify the ECR image URL, which we just pushed above.
#
# Finally, our local training dataset has to be in Amazon S3 and the S3 URL to our dataset is passed into the `fit()` call.
#
# Let's first fetch our ECR image url that corresponds to the image we just built and pushed.

# %%
import boto3

client = boto3.client('sts')
account = client.get_caller_identity()['Account']

my_session = boto3.session.Session()
region = my_session.region_name

algorithm_name = base_image_name
arch = 'gpu'

ecr_image = f'{account}.dkr.ecr.{region}.amazonaws.com/{algorithm_name}:1.0-{arch}-py37'

print(f'Using ECR image for training: {ecr_image}')
# Out:
# Using ECR image for training: 698042698196.dkr.ecr.us-west-2.amazonaws.com/sagemaker-fastai:1.0-gpu-py37

# %%
from sagemaker.estimator import Estimator

hyperparameters = {'epochs': 4, 'batch-size': 64}

instance_type_train = 'ml.p3.2xlarge'

estimator = PyTorch(entry_point='shirts.py',
                    source_dir=SRC_PATH,
                    role=role,
                    train_instance_count=1,
                    train_instance_type=instance_type_train,
                    image_name=ecr_image,
                    hyperparameters=hyperparameters)

estimator.fit(data_location)
# Out:
# WARNING:sagemaker:No framework_version specified, defaulting to version 0.4.
# INFO:sagemaker:Creating training-job with name: sagemaker-fastai-2018-11-19-08-06-14-296
# 2018-11-19 08:06:15 Starting - Starting the training job...
# 2018-11-19 08:06:16 Starting - Launching requested ML instances......
# 2018-11-19 08:07:21 Starting - Preparing the instances for training...
# 2018-11-19 08:08:01 Downloading - Downloading input data...
# 2018-11-19 08:08:18 Training - Downloading the training image......
# 2018-11-19 08:09:35 Training - Training image download completed. Training in progress.
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2018-11-19 08:09:36,265 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# 2018-11-19 08:09:36,286 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2018-11-19 08:09:37,697 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2018-11-19 08:09:37,963 sagemaker-containers INFO     Installing module with the following command:
# /usr/local/bin/python -m pip install -vvv -U .
# Created temporary directory: /tmp/pip-ephem-wheel-cache-d7_qh0c8
# Created temporary directory: /tmp/pip-req-tracker-rowv015s
# Created requirements tracker '/tmp/pip-req-tracker-rowv015s'
# Created temporary directory: /tmp/pip-install-m6fwhebr
# Processing /tmp/tmp20rrf40k/module_dir
#   Created temporary directory: /tmp/pip-req-build-wcupwv1p
#   Added file:///tmp/tmp20rrf40k/module_dir to build tracker '/tmp/pip-req-tracker-rowv015s'
#   Running setup.py (path:/tmp/pip-req-build-wcupwv1p/setup.py) egg_info for package from file:///tmp/tmp20rrf40k/module_dir
#     Running command python setup.py egg_info
#     WARNING: '' not a valid package name; please use only .-separated package names in setup.py
#     running egg_info
#     creating pip-egg-info/shirts.egg-info
#     writing pip-egg-info/shirts.egg-info/PKG-INFO
#     writing dependency_links to pip-egg-info/shirts.egg-info/dependency_links.txt
#     writing top-level names to pip-egg-info/shirts.egg-info/top_level.txt
#     writing manifest file 'pip-egg-info/shirts.egg-info/SOURCES.txt'
#     reading manifest file 'pip-egg-info/shirts.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     warning: no previously-included files matching '__pycache__*' found under directory '.'
#     warning: no previously-included files matching '*.pyc' found under directory '.'
#     warning: no previously-included files matching '*.pyo' found under directory '.'
#     writing manifest file 'pip-egg-info/shirts.egg-info/SOURCES.txt'
#   Source in /tmp/pip-req-build-wcupwv1p has version 1.0.0, which satisfies requirement shirts==1.0.0 from file:///tmp/tmp20rrf40k/module_dir
#   Removed shirts==1.0.0 from file:///tmp/tmp20rrf40k/module_dir from build tracker '/tmp/pip-req-tracker-rowv015s'
# Could not parse version from link: file:///tmp/tmp20rrf40k/module_dir
# Building wheels for collected packages: shirts
#   Created temporary directory: /tmp/pip-wheel-ytcdqp8y
#   Running setup.py bdist_wheel for shirts: started
#   Destination directory: /tmp/pip-wheel-ytcdqp8y
#   Running command /usr/local/bin/python -u -c "import setuptools, tokenize;__file__='/tmp/pip-req-build-wcupwv1p/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/pip-wheel-ytcdqp8y --python-tag cp37
#   WARNING: '' not a valid package name; please use only .-separated package names in setup.py
#   running bdist_wheel
#   The [wheel] section is deprecated. Use [bdist_wheel] instead.
#   running build
#   running build_py
#   creating build
#   creating build/lib
#   copying setup.py -> build/lib
#   copying shirts.py -> build/lib
#   running egg_info
#   creating shirts.egg-info
#   writing shirts.egg-info/PKG-INFO
#   writing dependency_links to shirts.egg-info/dependency_links.txt
#   writing top-level names to shirts.egg-info/top_level.txt
#   writing manifest file 'shirts.egg-info/SOURCES.txt'
#   reading manifest file 'shirts.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no previously-included files matching '__pycache__*' found under directory '.'
#   warning: no previously-included files matching '*.pyc' found under directory '.'
#   warning: no previously-included files matching '*.pyo' found under directory '.'
#   writing manifest file 'shirts.egg-info/SOURCES.txt'
#   copying MANIFEST.in -> build/lib
#   copying setup.cfg -> build/lib
#   copying pip-delete-this-directory.txt -> build/lib
#   creating build/lib/build
#   creating build/lib/build/lib
#   copying build/lib/setup.py -> build/lib/build/lib
#   copying build/lib/shirts.py -> build/lib/build/lib
#   creating build/lib/pip-egg-info
#   creating build/lib/pip-egg-info/shirts.egg-info
#   copying pip-egg-info/shirts.egg-info/PKG-INFO -> build/lib/pip-egg-info/shirts.egg-info
#   copying pip-egg-info/shirts.egg-info/SOURCES.txt -> build/lib/pip-egg-info/shirts.egg-info
#   copying pip-egg-info/shirts.egg-info/dependency_links.txt -> build/lib/pip-egg-info/shirts.egg-info
#   copying pip-egg-info/shirts.egg-info/top_level.txt -> build/lib/pip-egg-info/shirts.egg-info
#   creating build/lib/shirts.egg-info
#   copying shirts.egg-info/PKG-INFO -> build/lib/shirts.egg-info
#   copying shirts.egg-info/SOURCES.txt -> build/lib/shirts.egg-info
#   copying shirts.egg-info/dependency_links.txt -> build/lib/shirts.egg-info
#   copying shirts.egg-info/top_level.txt -> build/lib/shirts.egg-info
#   warning: build_py: byte-compiling is disabled, skipping.
#
#   installing to build/bdist.linux-x86_64/wheel
#   running install
#   running install_lib
#   creating build/bdist.linux-x86_64
#   creating build/bdist.linux-x86_64/wheel
#   copying build/lib/setup.cfg -> build/bdist.linux-x86_64/wheel
#   copying build/lib/pip-delete-this-directory.txt -> build/bdist.linux-x86_64/wheel
#   creating build/bdist.linux-x86_64/wheel/pip-egg-info
#   creating build/bdist.linux-x86_64/wheel/pip-egg-info/shirts.egg-info
#   copying build/lib/pip-egg-info/shirts.egg-info/PKG-INFO -> build/bdist.linux-x86_64/wheel/pip-egg-info/shirts.egg-info
#   copying build/lib/pip-egg-info/shirts.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/wheel/pip-egg-info/shirts.egg-info
#   copying build/lib/pip-egg-info/shirts.egg-info/top_level.txt -> build/bdist.linux-x86_64/wheel/pip-egg-info/shirts.egg-info
#   copying build/lib/pip-egg-info/shirts.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/wheel/pip-egg-info/shirts.egg-info
#   creating build/bdist.linux-x86_64/wheel/shirts.egg-info
#   copying build/lib/shirts.egg-info/PKG-INFO -> build/bdist.linux-x86_64/wheel/shirts.egg-info
#   copying build/lib/shirts.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/wheel/shirts.egg-info
#   copying build/lib/shirts.egg-info/top_level.txt -> build/bdist.linux-x86_64/wheel/shirts.egg-info
#   copying build/lib/shirts.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/wheel/shirts.egg-info
#   copying build/lib/setup.py -> build/bdist.linux-x86_64/wheel
#   copying build/lib/shirts.py -> build/bdist.linux-x86_64/wheel
#   copying build/lib/MANIFEST.in -> build/bdist.linux-x86_64/wheel
#   creating build/bdist.linux-x86_64/wheel/build
#   creating build/bdist.linux-x86_64/wheel/build/lib
#   copying build/lib/build/lib/setup.py -> build/bdist.linux-x86_64/wheel/build/lib
#   copying build/lib/build/lib/shirts.py -> build/bdist.linux-x86_64/wheel/build/lib
#   warning: install_lib: byte-compiling is disabled, skipping.
#
#   running install_egg_info
#   Copying shirts.egg-info to build/bdist.linux-x86_64/wheel/shirts-1.0.0-py3.7.egg-info
#   running install_scripts
#   creating build/bdist.linux-x86_64/wheel/shirts-1.0.0.dist-info/WHEEL
#   creating '/tmp/pip-wheel-ytcdqp8y/shirts-1.0.0-py2.py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
#   adding 'MANIFEST.in'
#   adding 'pip-delete-this-directory.txt'
#   adding 'setup.cfg'
#   adding 'setup.py'
#   adding 'shirts.py'
#   adding 'build/lib/setup.py'
#   adding 'build/lib/shirts.py'
#   adding 'pip-egg-info/shirts.egg-info/PKG-INFO'
#   adding 'pip-egg-info/shirts.egg-info/SOURCES.txt'
#   adding 'pip-egg-info/shirts.egg-info/dependency_links.txt'
#   adding 'pip-egg-info/shirts.egg-info/top_level.txt'
#   adding 'shirts.egg-info/PKG-INFO'
#   adding 'shirts.egg-info/SOURCES.txt'
#   adding 'shirts.egg-info/dependency_links.txt'
#   adding 'shirts.egg-info/top_level.txt'
#   adding 'shirts-1.0.0.dist-info/METADATA'
#   adding 'shirts-1.0.0.dist-info/WHEEL'
#   adding 'shirts-1.0.0.dist-info/top_level.txt'
#   adding 'shirts-1.0.0.dist-info/RECORD'
#   removing build/bdist.linux-x86_64/wheel
#   Running setup.py bdist_wheel for shirts: finished with status 'done'
#   Stored in directory: /tmp/pip-ephem-wheel-cache-d7_qh0c8/wheels/13/62/cb/75fd2be0c323a942db72cd83b4e81131a1af137299dddff29b
#   Removing source in /tmp/pip-req-build-wcupwv1p
# Successfully built shirts
# Installing collected packages: shirts
#
#   Removing source in /tmp/pip-install-m6fwhebr/shirts
# Successfully installed shirts-1.0.0
# Cleaning up...
# Removed build tracker '/tmp/pip-req-tracker-rowv015s'
# 2018-11-19 08:09:39,359 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch-size": 64,
#         "epochs": 4
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "job_name": "sagemaker-fastai-2018-11-19-08-06-14-296",
#     "log_level": 20,
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-698042698196/sagemaker-fastai-2018-11-19-08-06-14-296/source/sourcedir.tar.gz",
#     "module_name": "shirts",
#     "network_interface_name": "ethwe",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "ethwe"
#     }
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=ethwe
# SM_HPS={"batch-size":64,"epochs":4}
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"ethwe"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=shirts
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-698042698196/sagemaker-fastai-2018-11-19-08-06-14-296/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch-size":64,"epochs":4},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","job_name":"sagemaker-fastai-2018-11-19-08-06-14-296","log_level":20,"model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-698042698196/sagemaker-fastai-2018-11-19-08-06-14-296/source/sourcedir.tar.gz","module_name":"shirts","network_interface_name":"ethwe","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"ethwe"}}
# SM_USER_ARGS=["--batch-size","64","--epochs","4"]
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_BATCH-SIZE=64
# SM_HP_EPOCHS=4
#
# Invoking script with the following command:
#
# /usr/local/bin/python -m shirts --batch-size 64 --epochs 4
#
#
# Called _train method with model arch: resnet34, batch size: 64, image size: 224, epochs: 4
# Getting training data from dir: /opt/ml/input/data/training
# Model architecture is resnet34
# Creating pretrained conv net
# Fit four cycles
# epoch  train_loss  valid_loss  accuracy
# 1      0.487299    0.155635    0.945736
# 2      0.324014    0.101821    0.968992
# 3      0.236477    0.112947    0.965116
# 4      0.188889    0.106048    0.968992
# Unfreeze and run 4 more cycles
# epoch  train_loss  valid_loss  accuracy
# 1      0.107672    0.081665    0.980620
# 2      0.087061    0.083492    0.968992
# 3      0.064427    0.056322    0.980620
# 4      0.048806    0.061738    0.976744
# Saving model weights to dir: /opt/ml/model
# 2018-11-19 08:12:51,259 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2018-11-19 08:13:08 Uploading - Uploading generated training model
# 2018-11-19 08:13:08 Completed - Training job completed
# Billable seconds: 307

# %%
instance_type_deploy = 'ml.m5.xlarge'
arch = 'cpu'
ecr_image = f'{account}.dkr.ecr.{region}.amazonaws.com/{algorithm_name}:1.0-{arch}-py37'
print(f'Using ECR image for inference: {ecr_image}')

model = estimator.create_model()
model.predictor_cls=ImagePredictor
predictor = model.deploy(1, instance_type_deploy)
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-fastai-2018-11-19-08-06-14-296
# Using ECR image for inference: 698042698196.dkr.ecr.us-west-2.amazonaws.com/sagemaker-fastai:1.0-cpu-py37
# INFO:sagemaker:Creating endpoint with name sagemaker-fastai-2018-11-19-08-06-14-296
# ----------------------------------

# %%
# use on existing endpoint
#endpoint_name = ''
#predictor = ImagePredictor(endpoint=endpoint_name, sagemaker_session=my_session)

# %%
from PIL import Image
import requests
from io import BytesIO

# %%
# Motorhead T-Shirt
url = 'https://images.backstreetmerch.com/images/products/bands/clothing/mthd/bsi_mthd281.jpg'
# Judas Priest T-Shirt
#url = 'https://thumbs2.ebaystatic.com/d/l225/m/m7Lc1qRuFN3oFIlQla5V0IA.jpg'
# Australia Rugby T-Shirt
#url = 'https://www.lovell-rugby.co.uk/products/products_580x387/40378.jpg'
# Chicago Bulls top
#url = 'https://i.ebayimg.com/images/g/qc0AAOSwBahVN~qm/s-l300.jpg'
# Masters Golf Shirt
#url = 'https://s-media-cache-ak0.pinimg.com/originals/29/6a/15/296a15200e7dd3ed08e12d9052ea4f97.jpg'
img_bytes = requests.get(url).content
img = Image.open(BytesIO(img_bytes))
img

# %%
response = predictor.predict(img_bytes)
response

# %% [markdown]
# ## Optional cleanup
# When you're done with the endpoint, you should clean it up.
#
# All of the training jobs, models and endpoints we created can be viewed through the SageMaker console of your AWS account.

# %%
predictor.delete_endpoint()

# %% [markdown]
# # Reference
# - [How Amazon SageMaker interacts with your Docker container for training](https://docs.aws.amazon.com/sagemaker/latest/dg/your-algorithms-training-algo.html)
# - [How Amazon SageMaker interacts with your Docker container for inference](https://docs.aws.amazon.com/sagemaker/latest/dg/your-algorithms-inference-code.html)
# - [SageMaker Python SDK](https://github.com/aws/sagemaker-python-sdk)
# - [Dockerfile](https://docs.docker.com/engine/reference/builder/)
# - [PyTorch extending container example](https://github.com/awslabs/amazon-sagemaker-examples/blob/master/advanced_functionality/pytorch_extending_our_containers/pytorch_extending_our_containers.ipynb)
# - [scikit-bring-your-own example](https://github.com/awslabs/amazon-sagemaker-examples/blob/master/advanced_functionality/scikit_bring_your_own/scikit_bring_your_own.ipynb)
# - [SageMaker fast.ai container](https://github.com/mattmcclean/sagemaker-fastai-container)
# - [SageMaker fast.ai example](https://github.com/mattmcclean/sagemaker-fastai-example)
# - [SageMaker PyTorch container](https://github.com/aws/sagemaker-pytorch-container)
